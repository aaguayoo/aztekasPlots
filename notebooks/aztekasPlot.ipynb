# %%
from Aztekasplot.main import Plotter

# %%
plot = Plotter("./data.dat")

# %%
plot.data_dict
# Out:
# {'time': 59395.68,
#  'Nx1': 65,
#  'Nx2': 33,
#  'COORD': '33 ',
#  'x1': array([[  1.1     ,   1.182692,   1.272222, ..., 137.919   , 149.3156  ,
#          161.6545  ],
#         [  1.1     ,   1.182692,   1.272222, ..., 137.919   , 149.3156  ,
#          161.6545  ],
#         [  1.1     ,   1.182692,   1.272222, ..., 137.919   , 149.3156  ,
#          161.6545  ],
#         ...,
#         [  1.1     ,   1.182692,   1.272222, ..., 137.919   , 149.3156  ,
#          161.6545  ],
#         [  1.1     ,   1.182692,   1.272222, ..., 137.919   , 149.3156  ,
#          161.6545  ],
#         [  1.1     ,   1.182692,   1.272222, ..., 137.919   , 149.3156  ,
#          161.6545  ]]),
#  'x2': array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#          0.        ],
#         [0.04908739, 0.04908739, 0.04908739, ..., 0.04908739, 0.04908739,
#          0.04908739],
#         [0.09817477, 0.09817477, 0.09817477, ..., 0.09817477, 0.09817477,
#          0.09817477],
# ...
