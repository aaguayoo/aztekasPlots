# %%
from Aztekasplot.main import Plotter

# %%
plot = Plotter("./kerr-schild.dat",metric="Kerr-Schild",a_spin=0.0)

# %%
plot.initialize_plot(fontsize=14)
plot.set_axis(x1min=-3,X2_reflect=True)
plot.set_axis_ticks(ticks_decimals=0)
plot.set_axis_labels(x1_label="$X/M$")
plot.get_contour_plot(plot_var="rho",
                      cmap='inferno',
                      contour_color='black',
                      scale='log',
                      cbar_min = None,
                      cbar_max = None,
                      set_contour = True
)

# %%
plot = Plotter("./mink_cyl.dat")

# %%
plot.initialize_plot(figsize=(10,8),fontsize=16)
plot.set_axis(X2_reflect=True)
plot.set_axis_labels(x1_label="$R/M$", x2_label="$z/M$")
plot.set_axis_ticks(x1_ticks=[-12,-8,-4,0,4,8,12],x2_nticks=6)
plot.get_contour_plot(plot_var="rho",
                      cmap='inferno_r',
                      contour_color='black',
                      scale = 'log',
                      cbar_min = None,
                      cbar_max = None,
                      set_contour=False
                     )
plot.get_colorbar(bar_width=8,cbar_pad = 0.15, cbar_label="$\\log(\\rho/\\rho_0)$",labelpad=22)

# %%
plot.save_figure("bla.png")
